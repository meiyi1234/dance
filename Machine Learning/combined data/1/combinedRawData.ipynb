# %%
# data analysis
import pandas as pd
# import DataProcessing

#group
# chicken_data = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/1/chicken_dataset.csv')
# number7_data = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/1/number7_dataset.csv')
# sidestep_data = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/1/sidestep_dataset.csv')
# turnclap_data = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/1/turnclap_dataset.csv')
# wiper_data = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/1/wiper_dataset.csv')

# C:\Users\WEARE1\Desktop\cg3002\dance raw data\individual\bobby
#individual
# bobby_chicken = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/bobby/1/chicken.csv')
# bobby_number7 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/bobby/1/number7.csv')
# bobby_sidestep = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/bobby/1/sidestep.csv')
# bobby_turnclap = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/bobby/1/turnclap.csv')
# bobby_turnclap2 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/bobby/1/turnclap2.csv')
# bobby_wiper = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/bobby/1/wiper.csv')
bobby_number6  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/bobby/number6.csv')
bobby_salute   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/bobby/salute.csv')
bobby_mermaid  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/bobby/mermaid.csv')
bobby_swing    = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/bobby/swing.csv')
bobby_cowboy   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/bobby/cowboy.csv')
bobby_macarena = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/bobby/macarena.csv')
bobby_rest     = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/bobby/rest.csv')

# beeyee_chicken = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/beeyee/1/chicken.csv')
# beeyee_number7 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/beeyee/1/number7.csv')
# beeyee_sidestep = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/beeyee/1/sidestep.csv')
# beeyee_turnclap = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/beeyee/1/turnclap.csv')
# beeyee_turnclap2 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/beeyee/1/turnclap2.csv')
# beeyee_wiper = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/beeyee/1/wiper.csv')
beeyee_number6  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/beeyee/number6.csv')
beeyee_salute   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/beeyee/salute.csv')
beeyee_mermaid  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/beeyee/mermaid.csv')
beeyee_swing    = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/beeyee/swing.csv')
beeyee_cowboy   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/beeyee/cowboy.csv')
beeyee_macarena = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/beeyee/macarena.csv')

# henry_chicken = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/henry/1/chicken.csv')
# henry_number7 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/henry/1/number7.csv')
# # henry_number7_2 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/henry/1/number7-2.csv')
# henry_sidestep = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/henry/1/sidestep.csv')
# henry_turnclap1 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/henry/1/turnclap1.csv')
# henry_turnclap2 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/henry/1/turnclap2.csv')
# henry_turnclap3 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/henry/1/turnclap3.csv')
# henry_turnclap4 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/henry/1/turnclap4.csv')
# # henry_turnclap5 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/henry/1/turnclap5.csv')
# henry_wiper = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/henry/1/wiper.csv')
henry_number6   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/henry/number6.csv')
henry_salute    = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/henry/salute.csv')
henry_mermaid   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/henry/mermaid.csv')
henry_swing     = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/henry/swing.csv')
henry_cowboy1   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/henry/cowboy1.csv')
henry_cowboy2   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/henry/cowboy2.csv')
henry_cowboy3   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/henry/cowboy3.csv')
henry_cowboy4   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/henry/cowboy4.csv')
henry_cowboy5   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/henry/cowboy5.csv')
henry_macarena1 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/henry/macarena1.csv')
henry_macarena2 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/henry/macarena2.csv')

# kabir_chicken = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/kabir/1/chicken.csv')
# kabir_number7 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/kabir/1/number7.csv')
# kabir_sidestep = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/kabir/1/sidestep.csv')
# kabir_turnclap1 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/kabir/1/turnclap1.csv')
# kabir_turnclap2 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/kabir/1/turnclap2.csv')
# # kabir_turnclap3 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/kabir/turnclap3.csv')
# kabir_wiper = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/kabir/1/wiper.csv')
kabir_number6   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/kabir/number6.csv')
kabir_salute    = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/kabir/salute.csv')
kabir_mermaid   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/kabir/mermaid.csv')
kabir_swing     = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/kabir/swing.csv')
kabir_cowboy    = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/kabir/cowboy.csv')
kabir_macarena  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/kabir/macarena.csv')
kabir_rest      = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/kabir/rest.csv')

# zech_chicken = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/zech/1/chicken.csv')
# zech_number7 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/zech/1/number7.csv')
# zech_sidestep = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/zech/1/sidestep.csv')
# zech_turnclap1 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/zech/1/turnclap1.csv')
# zech_turnclap2 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/zech/1/turnclap2.csv')
# # zech_turnclap3 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/zech/1/turnclap3.csv')
# # zech_turnclap4 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/zech/1/turnclap4.csv')
# # zech_turnclap5 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/zech/1/turnclap5.csv')
# zech_wiper = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/zech/1/wiper.csv')
zech_number6  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/zech/number6.csv')
zech_salute   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/zech/salute.csv')
zech_mermaid  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/zech/mermaid.csv')
zech_swing    = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/zech/swing.csv')
zech_cowboy1  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/zech/cowboy1.csv')
zech_cowboy2  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/zech/cowboy2.csv')
zech_cowboy3  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/zech/cowboy3.csv')
zech_cowboy4  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/zech/cowboy4.csv')
zech_macarena = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/zech/macarena.csv')

# hongjing_chicken = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/hongjing/1/chicken.csv')
# hongjing_number7 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/hongjing/1/number7.csv')
# hongjing_sidestep = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/hongjing/1/sidestep.csv')
# # hongjing_turnclap1 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/hongjing/1/turnclap1.csv')
# hongjing_turnclap2 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/hongjing/1/turnclap2.csv')
# hongjing_turnclap3 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/hongjing/1/turnclap3.csv')
# hongjing_turnclap4 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/hongjing/1/turnclap4.csv')
# # hongjing_turnclap5 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/hongjing/1/turnclap5.csv')
# hongjing_wiper = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/hongjing/1/wiper.csv')
hongjing_number6  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/hongjing/number6.csv')
hongjing_salute   = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/hongjing/salute.csv')
hongjing_mermaid  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/hongjing/mermaid.csv')
hongjing_swing    = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/hongjing/swing.csv')
hongjing_cowboy1  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/hongjing/cowboy1.csv')
hongjing_cowboy2  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/hongjing/cowboy2.csv')
hongjing_cowboy3  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/hongjing/cowboy3.csv')
hongjing_cowboy4  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/hongjing/cowboy4.csv')
hongjing_cowboy5  = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/hongjing/cowboy5.csv')
hongjing_macarena = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/individual/2/hongjing/macarena.csv')

# frames_chicken = [bobby_chicken, beeyee_chicken, henry_chicken, kabir_chicken, zech_chicken, hongjing_chicken]
# frames_number7 = [bobby_number7, beeyee_number7, henry_chicken, kabir_number7, zech_number7, hongjing_number7]
# frames_sidestep = [bobby_sidestep, beeyee_sidestep, henry_sidestep, kabir_sidestep, zech_sidestep, hongjing_sidestep]
# frames_turnclap = [bobby_turnclap, bobby_turnclap2, beeyee_turnclap, beeyee_turnclap2, henry_turnclap1,
#                    henry_turnclap2, henry_turnclap3, henry_turnclap4, zech_turnclap1, zech_turnclap2,]
# frames_wiper = [bobby_wiper, beeyee_wiper, henry_wiper, kabir_wiper, zech_wiper, hongjing_wiper]
frames_number6  = [bobby_number6, beeyee_number6, henry_number6,  kabir_number6, zech_number6, hongjing_number6]
frames_salute   = [bobby_salute, beeyee_salute, henry_salute, kabir_salute, zech_salute, hongjing_salute]
frames_mermaid  = [bobby_mermaid, beeyee_mermaid, henry_mermaid, kabir_mermaid, zech_mermaid, hongjing_mermaid]
frames_swing    = [bobby_swing, beeyee_swing, henry_swing, kabir_swing, zech_swing, hongjing_swing]
frames_cowboy   = [bobby_cowboy, beeyee_cowboy, henry_cowboy1, henry_cowboy2, henry_cowboy3, henry_cowboy4, henry_cowboy5,
                     kabir_cowboy, zech_cowboy1, zech_cowboy2, zech_cowboy3, zech_cowboy4, hongjing_cowboy1, hongjing_cowboy2,
                     hongjing_cowboy3, hongjing_cowboy4, hongjing_cowboy5]
frames_macarena = [bobby_macarena, beeyee_macarena, henry_macarena1, henry_macarena2, kabir_macarena, zech_macarena, 
                   hongjing_macarena]
frames_rest     = [bobby_rest, kabir_rest]

# chicken_data = chicken_data.drop(['activity'], axis=1).copy()
# number7_data = number7_data.drop(['activity'], axis=1).copy()
# sidestep_data = sidestep_data.drop(['activity'], axis=1).copy()
# turnclap_data = turnclap_data.drop(['activity'], axis=1).copy()
# wiper_data = wiper_data.drop(['activity'], axis=1).copy()
# frames_chicken = [chicken_data, henry_chicken, hongjing_chicken]
# frames_number7 = [number7_data, henry_number7_1, henry_number7_2, hongjing_number7]
# frames_sidestep = [sidestep_data, henry_sidestep, hongjing_sidestep]
# frames_turnclap = [turnclap_data, henry_turnclap1, henry_turnclap2, henry_turnclap3, henry_turnclap4, 
#                    henry_turnclap5, hongjing_turnclap1, hongjing_turnclap2, hongjing_turnclap3, hongjing_turnclap4,
#                     hongjing_turnclap5]
# frames_wiper = [wiper_data, henry_wiper, hongjing_wiper]
# frames_chicken = [chicken_data, kabir_chicken, zech_chicken]
# frames_number7 = [number7_data, kabir_number7, zech_number7]
# frames_sidestep = [sidestep_data, kabir_sidestep, zech_sidestep]
# frames_turnclap = [turnclap_data, kabir_turnclap1, kabir_turnclap2, kabir_turnclap3, 
#                    zech_turnclap1, zech_turnclap2, zech_turnclap3, zech_turnclap4, zech_turnclap5]
# frames_wiper = [wiper_data, kabir_wiper, zech_wiper]

# chicken_data = pd.concat(frames_chicken)
# number7_data = pd.concat(frames_number7)
# sidestep_data = pd.concat(frames_sidestep)
# turnclap_data = pd.concat(frames_turnclap)
# wiper_data = pd.concat(frames_wiper)
number6_data  = pd.concat(frames_number6)
salute_data   = pd.concat(frames_salute)
mermaid_data  = pd.concat(frames_mermaid)
swing_data    = pd.concat(frames_swing)
cowboy_data   = pd.concat(frames_cowboy)
macarena_data = pd.concat(frames_macarena)
rest_data     = pd.concat(frames_rest)

# frames = [sidestep_data, bobby_sidestep]
# sidestep_data = pd.concat(frames)

# chicken_data['activity'] = 1;
# number7_data['activity'] = 2;
# sidestep_data['activity'] = 3;
# turnclap_data['activity'] = 4;
# wiper_data['activity'] = 5;
number6_data['activity']  = 6;
salute_data['activity']   = 7;
mermaid_data['activity']  = 8;
swing_data['activity']    = 9;
cowboy_data['activity']   = 10;
macarena_data['activity'] = 11;
rest_data['activity']     = 12;

# chicken_data.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/1/raw data/chicken_dataset.csv', index=False)
# number7_data.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/1/raw data/number7_dataset.csv', index=False)
# sidestep_data.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/1/raw data/sidestep_dataset.csv', index=False)
# turnclap_data.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/1/raw data/turnclap_dataset.csv', index=False)
# wiper_data.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/1/raw data/wiper_dataset.csv', index=False)
number6_data.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/2/raw data/number6_dataset.csv', index=False)
salute_data.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/2/raw data/salute_dataset.csv', index=False)
mermaid_data.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/2/raw data/mermaid_dataset.csv', index=False)
swing_data.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/2/raw data/swing_dataset.csv', index=False)
cowboy_data.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/2/raw data/cowboy_dataset.csv', index=False)
macarena_data.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/2/raw data/macarena_dataset.csv', index=False)
rest_data.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/2/raw data/rest_dataset.csv', index=False)

# chicken_data = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/1/raw data/chicken_dataset.csv')
# number7_data = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/1/raw data/number7_dataset.csv')
# sidestep_data = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/1/raw data/sidestep_dataset.csv')
# turnclap_data = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/1/raw data/turnclap_dataset.csv')
# wiper_data = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/1/raw data/wiper_dataset.csv')

# frames_result = [chicken_data, number7_data, sidestep_data, turnclap_data, wiper_data]
frames_result = [number6_data, salute_data, mermaid_data, swing_data, cowboy_data, macarena_data, rest_data]

result = pd.concat(frames_result)


result = result.drop(['voltage', 'current', 'power', 'energy'], axis = 1).copy()

print('done')

result.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/2/result/result2.csv', index=False)
# Out:
# done

# %%
result1 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/1/result/result1.csv')
result2 = pd.read_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/2/result/result2.csv')

frames_result = [result1,result2]
result = pd.concat(frames_result)

print('done')
result.to_csv(r'C:/Users/WEARE1/Desktop/cg3002/dance raw data/group/2/result/result_datasets.csv', index=False)
# Out:
# done
